# %%
from app_store_scraper import AppStore
from pprint import pprint
import pandas as pd
import random
from bs4 import BeautifulSoup
import urllib.request
import datetime
# data collection was done through python package app_store_scraper. 60,000 records were scrapped from Apple app store
# of region US. The data contain 60,000 reviews for the app chase and time ranges from 2008 to 2021

# %%
# Chase

# %%
reviews = AppStore(country="us", app_name="chase",app_id = 298867247)
reviews.review(how_many=100000,after = datetime.datetime(2019,12,31),sleep = random.randint(3,6))
# Out:
# 2021-05-12 18:09:56,275 [INFO] Base - Initialised: AppStore('us', 'chase', 298867247)
# 2021-05-12 18:09:56,280 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/chase/id298867247
# 2021-05-12 18:10:02,542 [INFO] Base - [id:298867247] Fetched 8 reviews (8 fetched in total)
# 2021-05-12 18:10:15,024 [INFO] Base - [id:298867247] Fetched 21 reviews (21 fetched in total)
# 2021-05-12 18:10:27,503 [INFO] Base - [id:298867247] Fetched 36 reviews (36 fetched in total)
# 2021-05-12 18:10:40,026 [INFO] Base - [id:298867247] Fetched 50 reviews (50 fetched in total)
# 2021-05-12 18:10:52,553 [INFO] Base - [id:298867247] Fetched 70 reviews (70 fetched in total)
# 2021-05-12 18:11:05,096 [INFO] Base - [id:298867247] Fetched 84 reviews (84 fetched in total)
# 2021-05-12 18:11:17,618 [INFO] Base - [id:298867247] Fetched 96 reviews (96 fetched in total)
# 2021-05-12 18:11:30,168 [INFO] Base - [id:298867247] Fetched 111 reviews (111 fetched in total)
# ...

# %%
review_text1 = []
review_title1 = []
user1 = []
rating1 = []
date1 = []
for review in reviews.reviews:
    review_text1.append(review['review'])
    review_title1.append(review['title'])
    user1.append(review['userName'])
    rating1.append(review['rating'])
    date1.append(review['date'])

# %%
data2019 = pd.DataFrame({'user':user1,'date':date1,'title':review_title1,'text':review_text1,'rating':rating1})

# %%
data2019
# Out:
#                  user                date  \
# 0           *dude1.0* 2020-06-17 17:44:58
# 1        cdjewell.net 2021-03-07 13:50:05
# 2          Zoeyxoxoxo 2020-06-03 00:42:12
# 3          Serge s... 2020-07-07 12:43:59
# 4            skippz14 2021-03-25 14:57:39
# ...               ...                 ...
# 6504  booty call 1:30 2021-01-07 23:57:55
# 6505       Trevor moo 2020-08-13 14:16:40
# 6506          azik_84 2020-02-16 11:54:37
# 6507            jlpad 2020-10-08 05:18:25
# 6508       jchauffeur 2020-03-04 20:10:00
#
#                                        title  \
# 0          Terrible Customer Service and App
# 1          Great but missing one key feature
# 2                If I could I’d put no stars
# 3     It's excellent, packed with technology
# 4      Closed my account for no known reason
# ...                                      ...
# 6504                                    Smdh
# 6505                                      👎🏽
# ...

# %%
data2019.dropna()
# Out:
#                  user                date  \
# 0           *dude1.0* 2020-06-17 17:44:58
# 1        cdjewell.net 2021-03-07 13:50:05
# 2          Zoeyxoxoxo 2020-06-03 00:42:12
# 3          Serge s... 2020-07-07 12:43:59
# 4            skippz14 2021-03-25 14:57:39
# ...               ...                 ...
# 6504  booty call 1:30 2021-01-07 23:57:55
# 6505       Trevor moo 2020-08-13 14:16:40
# 6506          azik_84 2020-02-16 11:54:37
# 6507            jlpad 2020-10-08 05:18:25
# 6508       jchauffeur 2020-03-04 20:10:00
#
#                                        title  \
# 0          Terrible Customer Service and App
# 1          Great but missing one key feature
# 2                If I could I’d put no stars
# 3     It's excellent, packed with technology
# 4      Closed my account for no known reason
# ...                                      ...
# 6504                                    Smdh
# 6505                                      👎🏽
# ...

# %%
ymd1 = []
year1 = []
month1 = []
for i in data2019.date:
    ymd1.append(i.date())
    year1.append(i.year)
    month1.append(i.month)

# %%
data2019['date'] = ymd1
data2019['year'] = year1
data2019['month'] = month1

# %%
data2019
# Out:
#                  user        date                                   title  \
# 0           *dude1.0*  2020-06-17       Terrible Customer Service and App
# 1        cdjewell.net  2021-03-07       Great but missing one key feature
# 2          Zoeyxoxoxo  2020-06-03             If I could I’d put no stars
# 3          Serge s...  2020-07-07  It's excellent, packed with technology
# 4            skippz14  2021-03-25   Closed my account for no known reason
# ...               ...         ...                                     ...
# 6504  booty call 1:30  2021-01-07                                    Smdh
# 6505       Trevor moo  2020-08-13                                      👎🏽
# 6506          azik_84  2020-02-16                                      👍🏻
# 6507            jlpad  2020-10-08                                       😿
# 6508       jchauffeur  2020-03-04                                       😢
#
#                                                    text  rating  year  month
# ...

# %%
data2019.to_csv('chaseReviews_2019after.csv', index = False)

# %%
reviews = AppStore(country="us", app_name="chase",app_id = 298867247)
reviews.review(how_many=60000,sleep = random.randint(3,6))
# Out:
# 2021-04-23 10:56:34,551 [INFO] Base - Initialised: AppStore('us', 'chase', 298867247)
# 2021-04-23 10:56:34,551 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/chase/id298867247
# 2021-04-23 10:56:39,736 [INFO] Base - [id:298867247] Fetched 20 reviews (20 fetched in total)
# 2021-04-23 10:56:50,018 [INFO] Base - [id:298867247] Fetched 60 reviews (60 fetched in total)
# 2021-04-23 10:57:00,244 [INFO] Base - [id:298867247] Fetched 100 reviews (100 fetched in total)
# 2021-04-23 10:57:10,457 [INFO] Base - [id:298867247] Fetched 140 reviews (140 fetched in total)
# 2021-04-23 10:57:20,636 [INFO] Base - [id:298867247] Fetched 180 reviews (180 fetched in total)
# 2021-04-23 10:57:30,957 [INFO] Base - [id:298867247] Fetched 220 reviews (220 fetched in total)
# 2021-04-23 10:57:41,246 [INFO] Base - [id:298867247] Fetched 260 reviews (260 fetched in total)
# 2021-04-23 10:57:51,677 [INFO] Base - [id:298867247] Fetched 300 reviews (300 fetched in total)
# ...

# %%
review_text = []
review_title = []
user = []
rating = []
date = []
for review in reviews.reviews:
    review_text.append(review['review'])
    review_title.append(review['title'])
    user.append(review['userName'])
    rating.append(review['rating'])
    date.append(review['date'])

# %%
data = pd.DataFrame({'user':user,'date':date,'title':review_title,'text':review_text,'rating':rating})

# %%
data
# Out:
#                   user                date  \
# 0      dangityourecute 2018-08-31 03:27:20
# 1            *dude1.0* 2020-06-17 17:44:58
# 2         cdjewell.net 2021-03-07 13:50:05
# 3           Zoeyxoxoxo 2020-06-03 00:42:12
# 4           Serge s... 2020-07-07 12:43:59
# ...                ...                 ...
# 59995      Csmithincin 2015-10-05 11:55:33
# 59996  Adam sefchovich 2015-10-05 00:40:21
# 59997        Goofy4u21 2015-10-04 20:31:14
# 59998           rmb317 2015-10-04 20:11:24
# 59999           T_NYCE 2015-10-04 18:37:27
#
#                                         title  \
# 0                        I love the chase app
# 1           Terrible Customer Service and App
# 2           Great but missing one key feature
# 3                 If I could I’d put no stars
# 4      It's excellent, packed with technology
# ...                                       ...
# 59995  Reliable, innovative and user friendly
# 59996                               Great app
# ...

# %%
data.dropna()
# Out:
#                   user                date  \
# 0      dangityourecute 2018-08-31 03:27:20
# 1            *dude1.0* 2020-06-17 17:44:58
# 2         cdjewell.net 2021-03-07 13:50:05
# 3           Zoeyxoxoxo 2020-06-03 00:42:12
# 4           Serge s... 2020-07-07 12:43:59
# ...                ...                 ...
# 59995      Csmithincin 2015-10-05 11:55:33
# 59996  Adam sefchovich 2015-10-05 00:40:21
# 59997        Goofy4u21 2015-10-04 20:31:14
# 59998           rmb317 2015-10-04 20:11:24
# 59999           T_NYCE 2015-10-04 18:37:27
#
#                                         title  \
# 0                        I love the chase app
# 1           Terrible Customer Service and App
# 2           Great but missing one key feature
# 3                 If I could I’d put no stars
# 4      It's excellent, packed with technology
# ...                                       ...
# 59995  Reliable, innovative and user friendly
# 59996                               Great app
# ...

# %%
data = pd.read_csv('chaseReviews_60000.csv')

# %%
data.head()
# Out:
#    Unnamed: 0             user                 date  \
# 0           0  dangityourecute  2018-08-31 03:27:20
# 1           1        *dude1.0*  2020-06-17 17:44:58
# 2           2     cdjewell.net  2021-03-07 13:50:05
# 3           3       Zoeyxoxoxo  2020-06-03 00:42:12
# 4           4       Serge s...  2020-07-07 12:43:59
#
#                                     title  \
# 0                    I love the chase app
# 1       Terrible Customer Service and App
# 2       Great but missing one key feature
# 3             If I could I’d put no stars
# 4  It's excellent, packed with technology
#
#                                                 text  rating
# 0  I’ve been using the app for over 4 years now a...       5
# 1  First of all I rarely leave negative reviews, ...       1
# 2  I have an embarrassing number of Chase account...       4
# 3  This app is TRASH. Matter of fact throw out th...       1
# 4  I have done a review of the chase app over a y...       5

# %%
from datetime import datetime as dt

# %%
ymd = []
year = []
month = []
for i in data.date:
    ymd.append(dt.strptime(i,'%Y-%m-%d %H:%M:%S').date())
    year.append(dt.strptime(i,'%Y-%m-%d %H:%M:%S').year)
    month.append(dt.strptime(i,'%Y-%m-%d %H:%M:%S').month)

# %%
data.pop('Unnamed: 0')
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 59995    59995
# 59996    59996
# 59997    59997
# 59998    59998
# 59999    59999
# Name: Unnamed: 0, Length: 60000, dtype: int64

# %%
data['date'] = ymd
data['year'] = year
data['month'] = month

# %%
data
# Out:
#                   user        date                                   title  \
# 0      dangityourecute  2018-08-31                    I love the chase app
# 1            *dude1.0*  2020-06-17       Terrible Customer Service and App
# 2         cdjewell.net  2021-03-07       Great but missing one key feature
# 3           Zoeyxoxoxo  2020-06-03             If I could I’d put no stars
# 4           Serge s...  2020-07-07  It's excellent, packed with technology
# ...                ...         ...                                     ...
# 59995      Csmithincin  2015-10-05  Reliable, innovative and user friendly
# 59996  Adam sefchovich  2015-10-05                               Great app
# 59997        Goofy4u21  2015-10-04                                 Amazing
# 59998           rmb317  2015-10-04                               Terrific!
# 59999           T_NYCE  2015-10-04                                Love it!
#
# ...

# %%
data.to_csv('chaseReviews_60000_clean.csv', index = False)

# %%
len(set(year))
# Out:
# 14

# %%
for i in set(year):
    print(i,year.count(i))
# Out:
# 2016 16150
# 2017 11088
# 2018 8666
# 2019 4505
# 2020 4680
# 2021 1622
# 2008 27
# 2009 222
# 2010 391
# 2011 323
# 2012 705
# 2013 695
# 2014 3969
# 2015 6957

# %%
# Capital One

# %%
reviews2 = AppStore(country="us", app_name="capital-one", app_id = 407558537)
reviews2.review(how_many=60000,sleep = random.randint(3,6))
# Out:
# 2021-04-23 20:24:54,176 [INFO] Base - Initialised: AppStore('us', 'capital-one', 407558537)
# 2021-04-23 20:24:54,176 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/capital-one/id407558537
# 2021-04-23 20:24:59,438 [INFO] Base - [id:407558537] Fetched 20 reviews (20 fetched in total)
# 2021-04-23 20:25:09,857 [INFO] Base - [id:407558537] Fetched 60 reviews (60 fetched in total)
# 2021-04-23 20:25:20,346 [INFO] Base - [id:407558537] Fetched 100 reviews (100 fetched in total)
# 2021-04-23 20:25:30,722 [INFO] Base - [id:407558537] Fetched 140 reviews (140 fetched in total)
# 2021-04-23 20:25:41,064 [INFO] Base - [id:407558537] Fetched 180 reviews (180 fetched in total)
# 2021-04-23 20:25:51,426 [INFO] Base - [id:407558537] Fetched 220 reviews (220 fetched in total)
# 2021-04-23 20:26:01,839 [INFO] Base - [id:407558537] Fetched 260 reviews (260 fetched in total)
# 2021-04-23 20:26:12,197 [INFO] Base - [id:407558537] Fetched 300 reviews (300 fetched in total)
# ...

# %%
review2_text = []
review2_title = []
user2 = []
rating2 = []
date2 = []
for review in reviews2.reviews:
    review2_text.append(review['review'])
    review2_title.append(review['title'])
    user2.append(review['userName'])
    rating2.append(review['rating'])
    date2.append(review['date'])

# %%
data2 = pd.DataFrame({'user':user2,'date':date2,'title':review2_title,'text':review2_text,'rating':rating2})

# %%
data2.dropna()
# Out:
#                     user                date  \
# 0                 anecbs 2021-01-15 01:11:22
# 1             DaJaBailey 2019-07-22 23:52:29
# 2             jeremy1927 2018-11-26 02:18:10
# 3                Rick904 2018-04-26 01:01:15
# 4          QueenB Pepper 2020-08-02 14:52:10
# ...                  ...                 ...
# 59995  Raging phone user 2020-03-21 15:31:55
# 59996         wendywiley 2020-02-17 20:57:35
# 59997   5GensInMyKitchen 2020-02-13 17:06:48
# 59998            ariGSWT 2020-02-04 21:56:42
# 59999            JS. 919 2020-01-12 13:06:43
#
#                                            title  \
# 0           Good app but quirky lately (UPDATED)
# 1      Not practical for deposit account holders
# 2                                   App”ic” Fail
# 3                                       Love it!
# 4             E-Bills Don’t show accurate status
# ...                                          ...
# 59995                                        App
# ...

# %%
data2.to_csv('capitaloneReviews_60000.csv')

# %%
data2 = pd.read_csv('capitaloneReviews_60000.csv')

# %%
data2
# Out:
#        Unnamed: 0               user                 date  \
# 0               0             anecbs  2021-01-15 01:11:22
# 1               1         DaJaBailey  2019-07-22 23:52:29
# 2               2         jeremy1927  2018-11-26 02:18:10
# 3               3            Rick904  2018-04-26 01:01:15
# 4               4      QueenB Pepper  2020-08-02 14:52:10
# ...           ...                ...                  ...
# 59995       59995  Raging phone user  2020-03-21 15:31:55
# 59996       59996         wendywiley  2020-02-17 20:57:35
# 59997       59997   5GensInMyKitchen  2020-02-13 17:06:48
# 59998       59998            ariGSWT  2020-02-04 21:56:42
# 59999       59999            JS. 919  2020-01-12 13:06:43
#
#                                            title  \
# 0           Good app but quirky lately (UPDATED)
# 1      Not practical for deposit account holders
# 2                                   App”ic” Fail
# 3                                       Love it!
# ...

# %%
ymd2 = []
year2 = []
month2 = []
for i in data2.date:
    ymd2.append(dt.strptime(i,'%Y-%m-%d %H:%M:%S').date())
    year2.append(dt.strptime(i,'%Y-%m-%d %H:%M:%S').year)
    month2.append(dt.strptime(i,'%Y-%m-%d %H:%M:%S').month)

# %%
data2.pop('Unnamed: 0')
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 59995    59995
# 59996    59996
# 59997    59997
# 59998    59998
# 59999    59999
# Name: Unnamed: 0, Length: 60000, dtype: int64

# %%
data2['date'] = ymd2
data2['year'] = year2
data2['month'] = month2

# %%
data2
# Out:
#                     user        date  \
# 0                 anecbs  2021-01-15
# 1             DaJaBailey  2019-07-22
# 2             jeremy1927  2018-11-26
# 3                Rick904  2018-04-26
# 4          QueenB Pepper  2020-08-02
# ...                  ...         ...
# 59995  Raging phone user  2020-03-21
# 59996         wendywiley  2020-02-17
# 59997   5GensInMyKitchen  2020-02-13
# 59998            ariGSWT  2020-02-04
# 59999            JS. 919  2020-01-12
#
#                                            title  \
# 0           Good app but quirky lately (UPDATED)
# 1      Not practical for deposit account holders
# 2                                   App”ic” Fail
# 3                                       Love it!
# 4             E-Bills Don’t show accurate status
# ...                                          ...
# 59995                                        App
# 59996                                 Wendywiley
# 59997                                          R
# ...

# %%
data2.to_csv('capitaloneReviews_60000_clean.csv',index = False)

# %%
for i in set(year2):
    print(i,year2.count(i))
# Out:
# 2017 2126
# 2018 13504
# 2019 24469
# 2020 18071
# 2021 1830

# %%
len(year2)
# Out:
# 60000

# %%
len(year)
# Out:
# 60000

# %%
from selenium import webdriver

# %%
url = 'https://apps.apple.com/us/app/chase-mobile-bank-invest/id298867247'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page,'html.parser')
v = soup.find('ul',{'class':'version-history__items'})
"""
versions = []
for i in v:
    versions.append(i.find('a').get_text())
"""
# Out:
# "\nversions = []\nfor i in v:\n    versions.append(i.find('a').get_text())\n"

# %%
print(v)
# Out:
# None

# %%
driver = webdriver.Chrome()
driver.get('https://apps.apple.com/us/app/chase-mobile-bank-invest/id298867247')
button = driver.find_element_by_id('modal-trigger-ember138')
button.click()

# %%
driver.switch_to_window(driver.window_handles[0])
page = driver.page_source.encode('utf-8')
# Out:
# <ipython-input-56-4d8acde237bb>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[0])

# %%
soup = BeautifulSoup(page,'html.parser')
v = soup.find('ul',{'class':'version-history__items'})

# %%
updates = v.find_all('li',{'class':'version-history__item'})

# %%
updates
# Out:
# [<li class="version-history__item">
#  <h4 class="version-history__item__version-number">4.192</h4>
#  <time aria-label="April 16, 2021" class="version-history__item__release-date" data-test-we-datetime="" datetime="2021-04-16T04:00:00.000Z">Apr 16, 2021</time>
#  <div aria-label="" class="we-truncate we-truncate--multi-line we-truncate--interactive we-truncate--truncated version-history__item__release-notes" dir="">
#  <div class="we-clamp" data-clamp="" ismorertl="false" style="height: 90px; -webkit-mask: linear-gradient(0deg, rgba(0, 0, 0, 0) 0px, rgba(0, 0, 0, 0) 18.0001px, rgb(0, 0, 0) 18.0001px), linear-gradient(270deg, rgba(0, 0, 0, 0) 0px, rgba(0, 0, 0, 0) 32.8px, rgb(0, 0, 0) 68.8002px);">
#  <p data-test-bidi="" dir="ltr">We've enhanced the Chase Mobile® app experience with new features that will allow our customers to do more in the app.</p>
#  <br/>
#  <p data-test-bidi="" dir="ltr">Now you can:</p>
# ...

# %%
d = []

text = []
version = []
for i in updates:
    version.append(i.find('h4',{'class':'version-history__item__version-number'}).get_text())
    d.append(i.find('time',{'class':'version-history__item__release-date'}).get_text())
    p = i.find_all('p')
    t = ''
    for n in p:
        t += n.get_text()
    text.append(t)

# %%
print(len(text),len(d),len(version))
# Out:
# 25 25 25

# %%
updateInfo = pd.DataFrame({'version':version,'date':d,'content':text})

# %%
updateInfo
# Out:
#    version          date                                            content
# 0    4.192  Apr 16, 2021  We've enhanced the Chase Mobile® app experienc...
# 1    4.191  Apr 13, 2021  We've enhanced the Chase Mobile® app experienc...
# 2    4.190   Apr 6, 2021  We've enhanced the Chase Mobile® app experienc...
# 3    4.181   Mar 3, 2021  We're frequently updating the app in order to ...
# 4    4.180  Feb 23, 2021  We're frequently updating the app in order to ...
# 5    4.172  Jan 28, 2021  We're frequently updating the app in order to ...
# 6    4.171  Dec 10, 2020  We've enhanced the Chase Mobile® app experienc...
# 7    4.170   Dec 3, 2020  We've enhanced the Chase Mobile® app experienc...
# 8    4.160   Nov 5, 2020  We're frequently updating the app in order to ...
# 9    4.153   Oct 9, 2020  We've enhanced the Chase Mobile® app experienc...
# 10   4.152   Oct 3, 2020  We've enhanced the Chase Mobile® app experienc...
# ...

# %%
updateInfo.to_csv('updateInfo.csv')
